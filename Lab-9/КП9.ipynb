# %% [markdown]
# ##<center>__Самостійні завдання__</center>
#
# > Скопіювати блок самостійних завдань в окремий файл ***LastName_CP9.ipynb***
#
# > Інсталюйте необхідні пакети бібліотек Python

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import cluster
from sklearn import preprocessing
# %matplotlib inline

# %% [markdown]
# ### Завдання №1
#
# * Завантажте дані з лінку
#
# `url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"`
#
# <center><img src="http://sebastianraschka.com/images/blog/2015/principal_component_analysis_files/iris.png" width="600" alt="content-vs-colab.png"></center>
#
# * задайте наступні імена колонок датафрейму:
#
# `names=['sepal length','sepal width','petal length','petal width','class label']`
# * виведіть описову статистику датасету
# * сформуйте масив характеристик $X$, використовуйте лише `sepal length` та `sepal width`
# * Побудуйте точковий графік даних характеристик відносно відомих класів

# %%
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")
df.columns = ['sepal length','sepal width','petal length','petal width','class label']
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width  class label
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %%
df.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.848322     3.051007      3.774497     1.205369
# std        0.828594     0.433499      1.759651     0.761292
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
X = df[["sepal length", "sepal width"]]

# %%
plt.scatter(X["sepal width"], X["sepal length"])
plt.xlabel("sepal width")
plt.ylabel("sepal length")
# Out:
# Text(0, 0.5, 'sepal length')

# %% [markdown]
# ### Завдання №2
#
# * Проведіть стандартизацію даних
# * застосуйте алгоритм $k$-means для $k=2$, $k=3$, $k=4$ з оптимізацією та без, побудуйте діаграми кластерів
# * порівняйте результати кластеризації при $k=3$ з діаграмою класів
# * побудуйте залежність кількості кластерів $k$ та квадратичного критерію інерції
# * зробіть висновки

# %%
SS = preprocessing.StandardScaler()
stand_X = SS.fit_transform(X)

# %%
def KMeans_clust(X, clusterNum, init="k-means++", n_init=1, max_iter=1):
    k_means = cluster.KMeans(
        init="k-means++", 
        n_clusters=clusterNum, 
        n_init=n_init,
        max_iter=max_iter
    )
    k_means.fit(X)
    labels = k_means.labels_
    plt.scatter(X["sepal width"], X["sepal length"], c=labels.astype(np.float), alpha=0.5)
    plt.xlabel('sepal width', fontsize=18)
    plt.ylabel('sepal length', fontsize=16)
    plt.show()

# %%
KMeans_clust(X, 2, init="random")
# Out:
# <ipython-input-7-1a6e20e9113c>:10: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   plt.scatter(X["sepal width"], X["sepal length"], c=labels.astype(np.float), alpha=0.5)

# %%
KMeans_clust(X, 2, n_init=10, max_iter=100)
# Out:
# <ipython-input-7-1a6e20e9113c>:10: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   plt.scatter(X["sepal width"], X["sepal length"], c=labels.astype(np.float), alpha=0.5)

# %%
KMeans_clust(X, 3, init="random")
# Out:
# <ipython-input-7-1a6e20e9113c>:10: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   plt.scatter(X["sepal width"], X["sepal length"], c=labels.astype(np.float), alpha=0.5)

# %%
KMeans_clust(X, 3, n_init=10, max_iter=100)
# Out:
# <ipython-input-7-1a6e20e9113c>:10: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   plt.scatter(X["sepal width"], X["sepal length"], c=labels.astype(np.float), alpha=0.5)

# %%
KMeans_clust(X, 4, init="random")
# Out:
# <ipython-input-7-1a6e20e9113c>:10: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   plt.scatter(X["sepal width"], X["sepal length"], c=labels.astype(np.float), alpha=0.5)

# %%
KMeans_clust(X, 4, n_init=10, max_iter=100)
# Out:
# <ipython-input-7-1a6e20e9113c>:10: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   plt.scatter(X["sepal width"], X["sepal length"], c=labels.astype(np.float), alpha=0.5)

# %%
ks = range(1, 10)
inertias = []

for k in ks:
    model = cluster.KMeans(n_clusters=k)
    model.fit(X)
    inertias.append(model.inertia_)

plt.figure(figsize=(8,5))
plt.style.use('bmh')
plt.plot(ks, inertias, '-o')
plt.xlabel('Number of clusters, k')
plt.ylabel('Inertia')
plt.xticks(ks)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# ### Завдання №3
#
# * застосуйте алгоритм `DBSCAN`та побудуйте діаграму кластерів
# * зробіть висновки

# %%
dbscan = cluster.DBSCAN(eps=0.3,min_samples=5,metric="euclidean")

# %%
labels = dbscan.fit_predict(X)

# %%
plt.scatter(X["sepal width"], X["sepal length"], c=labels.astype(np.float), alpha=0.5)
plt.xlabel('sepal width', fontsize=18)
plt.ylabel('sepal length', fontsize=16)
plt.show()
# Out:
# <ipython-input-17-b7f2af1fa7a3>:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   plt.scatter(X["sepal width"], X["sepal length"], c=labels.astype(np.float), alpha=0.5)

# %% [markdown]
# ### Завдання №4
#
# * застосуйте алгоритм агломеративної ієрархії та побудуйте діаграму кластерів
# * побудуйте дендрограму
# * зробіть висновки

# %%
ac = cluster.AgglomerativeClustering(n_clusters=3,affinity="euclidean",linkage="complete")

# %%
labels = ac.fit_predict(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
plt.scatter(X["sepal width"], X["sepal length"], c=labels.astype(np.float), alpha=0.5)
plt.xlabel('sepal width', fontsize=18)
plt.ylabel('sepal length', fontsize=16)
plt.show()
# Out:
# <ipython-input-20-b7f2af1fa7a3>:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   plt.scatter(X["sepal width"], X["sepal length"], c=labels.astype(np.float), alpha=0.5)

# %%
from scipy.spatial import distance_matrix 
dist_matrix = distance_matrix(X,X) 
print(dist_matrix)
# Out:
# [[0.         0.28284271 0.31622777 ... 1.6        1.36014705 1.        ]
#  [0.28284271 0.         0.14142136 ... 1.81107703 1.5132746  1.21655251]
#  [0.31622777 0.14142136 0.         ... 1.90262976 1.62788206 1.30384048]
#  ...
#  [1.6        1.81107703 1.90262976 ... 0.         0.5        0.6       ]
#  [1.36014705 1.5132746  1.62788206 ... 0.5        0.         0.5       ]
#  [1.         1.21655251 1.30384048 ... 0.6        0.5        0.        ]]

# %%
from scipy.cluster import hierarchy 
Z = hierarchy.linkage(dist_matrix, 'complete')
# Out:
# <ipython-input-22-d7b2827b4c7b>:2: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = hierarchy.linkage(dist_matrix, 'complete')

# %%
dendro = hierarchy.dendrogram(Z)

# %% [markdown]
# ### Завдання №5
#
# * порівняйте результати кластеризації методами $k$-means, DBSCAN та агломеративної ієрархії
# * зробіть висновки

# %% [markdown]
# В рамках даної роботи було використано бібліотеку sklearn для кластеризації даних. Було використано 3 методи: K-Menas, DBScan та Hierarchical Clustering. Також для K-Menas була використана різна кількість кластерів. Аналізуючи резульитати, можна сказати, що найкраще себе показав метод K-Means із 3-ма кластерами. Метод DBSCAN показав себе непогано, але через нерівномірну щільність дав не дуже точне розбиття.
